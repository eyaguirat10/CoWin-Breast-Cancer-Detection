# %% [markdown]
# <a href="https://colab.research.google.com/github/eyaguirat10/CoWin-Breast-Cancer-Detection/blob/main/Breast_Cancer_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Business Understanding

# %% [markdown]
# Summary:
# The project aims to improve breast cancer diagnosis by automating the classification of tumors (benign or malignant) using machine learning algorithms on the Wisconsin Diagnostic Breast Cancer (WDBC) dataset. The business motivation is to assist medical practitioners in early and accurate detection, reducing diagnostic time and human error while enhancing patient outcomes and decision support

# %% [markdown]
# # II. Data Understanding

# %% [markdown]
# #III. Data Preparation

# %% [markdown]
# #IV. Modeling

# %% [markdown]
# #V. Evaluation

# %% [markdown]
# #VI. Deployment
